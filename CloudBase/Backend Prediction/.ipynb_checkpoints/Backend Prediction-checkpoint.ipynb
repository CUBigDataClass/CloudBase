# %%
import pandas as pd
import math
import csv
import random
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import cross_val_score

# %%
df1  =  pd.read_csv("15-16Miscellaneous_Stat.csv")
df2  =   pd.read_csv("15-16Opponent_Per_Game_Stat.csv")
df3  =   pd.read_csv("15-16Team_Per_Game_Stat.csv")
schedule = pd.read_csv("16-17Schedule.csv")
pastresult   = pd.read_csv("2015-2016_result.csv")

# %%
base_elo = 1600
team_elos = {} 
team_stats = {}
X = []
y = []
folder = 'data'

# %%
def initialize_data(Mstat, Ostat, Tstat):
    new_Mstat = Mstat.drop(['Rk', 'Arena'], axis=1)
    new_Ostat = Ostat.drop(['Rk', 'G', 'MP'], axis=1)
    new_Tstat = Tstat.drop(['Rk', 'G', 'MP'], axis=1)

    team_stats1 = pd.merge(new_Mstat, new_Ostat, how='left', on='Team')
    team_stats1 = pd.merge(team_stats1, new_Tstat, how='left', on='Team')
    return team_stats1.set_index('Team', inplace=False, drop=True)

# %%
def get_elo(team):
    try:
        return team_elos[team]
    except:
        # 当最初没有elo时，给每个队伍最初赋base_elo
        team_elos[team] = base_elo
        return team_elos[team]

# %%
def calc_elo(win_team, lose_team):
    winner_rank = get_elo(win_team)
    loser_rank = get_elo(lose_team)

    rank_diff = winner_rank - loser_rank
    exp = (rank_diff  * -1) / 400
    odds = 1 / (1 + math.pow(10, exp))
    # 根据rank级别修改K值
    if winner_rank < 2100:
        k = 32
    elif winner_rank >= 2100 and winner_rank < 2400:
        k = 24
    else:
        k = 16
    
    # 更新 rank 数值
    new_winner_rank = round(winner_rank + (k * (1 - odds)))      
    new_loser_rank = round(loser_rank + (k * (0 - odds)))
    return new_winner_rank, new_loser_rank

# %%
def  build_dataSet(all_data):
    print("Building data set..")
    X = []
    skip = 0
    for index, row in all_data.iterrows():

        Wteam = row['WTeam']
        Lteam = row['LTeam']

        #获取最初的elo或是每个队伍最初的elo值
        team1_elo = get_elo(Wteam)
        team2_elo = get_elo(Lteam)

        # 给主场比赛的队伍加上100的elo值
        if row['WLoc'] == 'H':
            team1_elo += 100
        else:
            team2_elo += 100

        # 把elo当为评价每个队伍的第一个特征值
        team1_features = [team1_elo]
        team2_features = [team2_elo]

        # 添加我们从basketball reference.com获得的每个队伍的统计信息
        for key, value in team_stats.loc[Wteam].iteritems():
            team1_features.append(value)
        for key, value in team_stats.loc[Lteam].iteritems():
            team2_features.append(value)

        # 将两支队伍的特征值随机的分配在每场比赛数据的左右两侧
        # 并将对应的0/1赋给y值
        if np.random.random() > 0.5:
            X.append(team1_features + team2_features)
            y.append(0)
        else:
            X.append(team2_features + team1_features)
            y.append(1)

        if skip == 0:
            print('X',X)
            skip = 1

        # 根据这场比赛的数据更新队伍的elo值
        new_winner_rank, new_loser_rank = calc_elo(Wteam, Lteam)
        team_elos[Wteam] = new_winner_rank
        team_elos[Lteam] = new_loser_rank

    return np.nan_to_num(X), y

# %%
if __name__ == '__main__':

    Mstat = df1
    Ostat = df2
    Tstat = df3
    team_stats = initialize_data(Mstat, Ostat, Tstat)
    print(team_stats)
    result_data = pastresult
    X, y = build_dataSet(result_data)

    # 训练网络模型
    #print("Fitting on %d game samples.." % len(X))

    model = linear_model.LogisticRegression()
    model.fit(X, y)

    # 利用10折交叉验证计算训练正确率
    #print("Doing cross-validation..")
    #print(cross_val_score(model, X, y, cv = 10, scoring='accuracy', n_jobs=-1).mean())
# Out:
# 1,                          Age   W   L  PW  PL    MOV   SOS    SRS   ORtg  \
# Team
# Golden State Warriors   27.4  73   9  65  17  10.76 -0.38  10.38  114.5
# San Antonio Spurs       30.3  67  15  67  15  10.63 -0.36  10.28  110.3
# Oklahoma City Thunder   25.8  55  27  59  23   7.28 -0.19   7.09  113.1
# Cleveland Cavaliers     28.1  57  25  57  25   6.00 -0.55   5.45  110.9
# Los Angeles Clippers    29.7  53  29  53  29   4.28 -0.15   4.13  108.3
# Toronto Raptors         26.3  56  26  53  29   4.50 -0.42   4.08  110.0
# Atlanta Hawks           28.2  48  34  51  31   3.61 -0.12   3.49  105.1
# Boston Celtics          25.2  48  34  50  32   3.21 -0.37   2.84  106.8
# Charlotte Hornets       26.0  48  34  49  33   2.72 -0.36   2.36  107.1
# Utah Jazz               24.2  40  42  46  36   1.79  0.05   1.84  105.9
# Indiana Pacers          26.9  45  37  46  36   1.71 -0.09   1.62  104.6
# Miami Heat              28.4  48  34  46  36   1.65 -0.14   1.50  106.1
# Portland Trail Blazers  24.3  44  38  43  39   0.83  0.15   0.98  108.8
# Detroit Pistons         25.0  44  38  43  39   0.61 -0.18   0.43  106.1
# Houston Rockets         27.8  41  41  42  40   0.20  0.14   0.34  108.3
# Dallas Mavericks        30.3  42  40  40  42  -0.30  0.29  -0.02  106.7
# Washington Wizards      27.3  41  41  40  42  -0.50  0.00  -0.50  105.3
# Chicago Bulls           27.6  42  40  37  45  -1.48  0.01  -1.46  105.0
# Orlando Magic           23.9  35  47  36  46  -1.62 -0.06  -1.68  105.1
# Memphis Grizzlies       30.5  42  40  35  47  -2.24  0.11  -2.14  105.4
# Sacramento Kings        26.6  33  49  34  48  -2.48  0.16  -2.32  106.0
# New York Knicks         27.2  32  50  33  49  -2.73  0.00  -2.74  104.6
# Denver Nuggets          24.7  33  49  33  49  -3.10  0.29  -2.81  105.6
# Minnesota Timberwolves  24.6  29  53  31  51  -3.54  0.15  -3.38  106.5
# New Orleans Pelicans    26.6  30  52  31  51  -3.79  0.24  -3.56  105.6
# Milwaukee Bucks         23.5  33  49  29  53  -4.18  0.20  -3.98  104.3
# Phoenix Suns            26.0  23  59  24  58  -6.66  0.34  -6.32  102.2
# Brooklyn Nets           26.9  21  61  22  60  -7.35  0.24  -7.12  103.2
# Los Angeles Lakers      26.5  17  65  17  65  -9.56  0.64  -8.92  101.6
# Philadelphia 76ers      23.3  10  72  16  66 -10.23  0.31  -9.92   98.8
#
#                          DRtg  ...    FT%_y  ORB_y  DRB_y  TRB_y  AST_y  \
# Team                           ...
# Golden State Warriors   103.8  ...    0.763   10.0   36.2   46.2   28.9
# San Antonio Spurs        99.0  ...    0.803    9.4   34.5   43.9   24.5
# Oklahoma City Thunder   105.6  ...    0.782   13.1   35.6   48.6   23.0
# Cleveland Cavaliers     104.5  ...    0.748   10.6   33.9   44.5   22.7
# Los Angeles Clippers    103.8  ...    0.692    8.8   33.3   42.0   22.8
# Toronto Raptors         105.2  ...    0.777   10.2   33.2   43.4   18.7
# Atlanta Hawks           101.4  ...    0.783    8.3   33.8   42.1   25.6
# Boston Celtics          103.6  ...    0.788   11.6   33.3   44.9   24.2
# Charlotte Hornets       104.3  ...    0.790    9.0   35.0   43.9   21.7
# Utah Jazz               103.9  ...    0.744   10.7   32.5   43.2   19.0
# Indiana Pacers          102.9  ...    0.764   10.3   33.9   44.2   21.2
# Miami Heat              104.4  ...    0.744    9.8   34.3   44.1   20.8
# Portland Trail Blazers  108.0  ...    0.754   11.6   33.9   45.5   21.3
# Detroit Pistons         105.5  ...    0.668   12.5   33.9   46.3   19.4
# Houston Rockets         108.1  ...    0.694   11.3   31.7   43.1   22.2
# Dallas Mavericks        107.0  ...    0.794    9.2   33.9   43.1   22.1
# Washington Wizards      105.8  ...    0.730    9.1   32.8   41.8   24.5
# Chicago Bulls           106.5  ...    0.787   11.1   35.2   46.3   22.8
# Orlando Magic           106.8  ...    0.757   10.3   33.0   43.3   23.6
# Memphis Grizzlies       107.8  ...    0.783   11.2   30.5   41.6   20.7
# Sacramento Kings        108.4  ...    0.725   10.6   33.7   44.2   24.5
# New York Knicks         107.6  ...    0.805   10.4   34.0   44.4   20.5
# Denver Nuggets          108.9  ...    0.766   11.5   33.1   44.6   22.7
# Minnesota Timberwolves  110.1  ...    0.792   10.0   31.5   41.6   23.4
# New Orleans Pelicans    109.5  ...    0.776    9.5   33.1   42.6   22.2
# Milwaukee Bucks         108.7  ...    0.747   10.5   31.2   41.7   23.1
# Phoenix Suns            109.0  ...    0.751   11.5   33.3   44.8   20.7
# Brooklyn Nets           110.9  ...    0.757   10.5   31.9   42.4   22.3
# Los Angeles Lakers      111.6  ...    0.781   10.7   32.3   43.0   18.0
# Philadelphia 76ers      109.2  ...    0.694    9.5   31.8   41.2   21.5
#
#                         STL_y  BLK_y  TOV_y  PF_y  PTS_y
# Team
# Golden State Warriors     8.4    6.1   15.2  20.7  114.9
# San Antonio Spurs         8.3    5.9   13.1  17.5  103.5
# Oklahoma City Thunder     7.4    5.9   15.9  20.6  110.2
# Cleveland Cavaliers       6.7    3.9   13.6  20.3  104.3
# Los Angeles Clippers      8.6    5.6   13.0  21.3  104.5
# Toronto Raptors           7.8    5.5   13.1  19.6  102.7
# Atlanta Hawks             9.1    5.9   15.0  19.1  102.8
# Boston Celtics            9.2    4.2   13.7  21.9  105.7
# Charlotte Hornets         7.3    5.3   12.6  18.1  103.4
# Utah Jazz                 7.7    5.2   14.9  20.2   97.7
# Indiana Pacers            9.0    4.8   14.9  20.0  102.2
# Miami Heat                6.7    6.5   14.1  18.3  100.0
# Portland Trail Blazers    6.9    4.6   14.6  21.7  105.1
# Detroit Pistons           7.0    3.7   13.5  19.0  102.0
# Houston Rockets          10.0    5.2   15.9  21.8  106.5
# Dallas Mavericks          6.8    3.7   12.8  19.5  102.3
# Washington Wizards        8.6    3.9   14.5  20.8  104.1
# Chicago Bulls             6.0    5.7   13.9  18.8  101.6
# Orlando Magic             8.2    5.1   14.1  20.7  102.1
# Memphis Grizzlies         8.8    4.3   13.3  21.7   99.1
# Sacramento Kings          8.9    4.5   16.2  20.4  106.6
# New York Knicks           5.7    5.7   13.4  19.7   98.4
# Denver Nuggets            7.4    4.8   14.7  21.0  101.9
# Minnesota Timberwolves    8.0    4.6   15.0  20.7  102.4
# New Orleans Pelicans      7.7    4.2   13.4  20.9  102.7
# Milwaukee Bucks           8.2    5.8   15.2  20.7   99.0
# Phoenix Suns              7.7    3.8   17.2  22.7  100.9
# Brooklyn Nets             7.6    4.0   14.8  18.0   98.6
# Los Angeles Lakers        7.2    4.1   13.7  20.3   97.3
# Philadelphia 76ers        8.3    6.0   16.4  21.7   97.4
#
# [30 rows x 65 columns]
# Building data set..
# X [[1477, 28.2, 48.0, 34.0, 51.0, 31.0, 3.61, -0.12, 3.49, 105.1, 101.4, 97.1, 0.237, 0.336, 0.552, 0.516, 13.8, 19.1, 0.185, 0.48, 14.4, 74.6, 0.19399999999999998, 690150.0, 37.1, 86.1, 0.43200000000000005, 8.3, 24.5, 0.33799999999999997, 28.9, 61.6, 0.469, 16.7, 22.1, 0.755, 11.5, 35.0, 46.5, 22.0, 8.6, 5.0, 16.1, 18.3, 99.2, 38.6, 84.4, 0.45799999999999996, 9.9, 28.4, 0.35, 28.7, 56.1, 0.512, 15.6, 20.0, 0.7829999999999999, 8.3, 33.8, 42.1, 25.6, 9.1, 5.9, 15.0, 19.1, 102.8, 259, 27.2, 32.0, 50.0, 33.0, 49.0, -2.73, 0.0, -2.74, 104.6, 107.6, 93.4, 0.255, 0.256, 0.527, 0.483, 12.6, 23.7, 0.205, 0.48700000000000004, 10.5, 75.8, 0.204, 812292.0, 38.0, 85.8, 0.44299999999999995, 7.6, 22.4, 0.341, 30.3, 63.4, 0.479, 17.5, 23.2, 0.754, 10.9, 33.3, 44.2, 20.8, 7.2, 4.2, 11.3, 18.5, 101.1, 36.9, 84.0, 0.439, 7.4, 21.5, 0.34600000000000003, 29.4, 62.5, 0.47100000000000003, 17.2, 21.4, 0.805, 10.4, 34.0, 44.4, 20.5, 5.7, 5.7, 13.4, 19.7, 98.4]]
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-7d95d2d63ffc> in <module>
#      13
#      14     model = linear_model.LogisticRegression()
# ---> 15     model.fit(X, y)
#      16
#      17     # 利用10折交叉验证计算训练正确率
#
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1283
#    1284         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1285                          accept_large_sparse=solver != 'liblinear')
#    1286         check_classification_targets(y)
#    1287         self.classes_ = np.unique(y)
#
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     764         y = y.astype(np.float64)
#     765
# --> 766     check_consistent_length(X, y)
#     767
#     768     return X, y
#
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     233     if len(uniques) > 1:
#     234         raise ValueError("Found input variables with inconsistent numbers of"
# --> 235                          " samples: %r" % [int(l) for l in lengths])
#     236
#     237
#
# ValueError: Found input variables with inconsistent numbers of samples: [1316, 3948]

# %%
def predict_winner(team_1, team_2, model):
    features = []

    # team 1，客场队伍
    features.append(get_elo(team_1))
    for key, value in team_stats.loc[team_1].iteritems():
        features.append(value)

    # team 2，主场队伍
    features.append(get_elo(team_2) + 100)
    for key, value in team_stats.loc[team_2].iteritems():
        features.append(value)

    features = np.nan_to_num(features)
    return model.predict_proba([features])

# %%
# 利用训练好的model在16-17年的比赛中进行预测

print('Predicting on new schedule..')
schedule1617 = schedule
result = []
for index, row in schedule1617.iterrows():
    team1 = row['Vteam']
    team2 = row['Hteam']
    pred = predict_winner(team1, team2, model)
    prob = pred[0][0]
    if prob > 0.5:
        winner = team1
        loser = team2
        result.append([winner, loser, prob])
    else:
        winner = team2
        loser = team1
        result.append([winner, loser, 1 - prob])

with open('16-17Result.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['win', 'lose', 'probability'])
    writer.writerows(result)
    print('done.')
pd.read_csv('16-17Result.csv',header=0)
# Out:
# Predicting on new schedule..
# done.
#                          win                    lose  probability
# 0        Cleveland Cavaliers         New York Knicks     0.863064
# 1      Golden State Warriors       San Antonio Spurs     0.514101
# 2     Portland Trail Blazers               Utah Jazz     0.525198
# 3             Boston Celtics           Brooklyn Nets     0.904891
# 4             Indiana Pacers        Dallas Mavericks     0.583867
# 5            Houston Rockets      Los Angeles Lakers     0.824441
# 6          Memphis Grizzlies  Minnesota Timberwolves     0.669173
# 7          Charlotte Hornets         Milwaukee Bucks     0.758661
# 8             Denver Nuggets    New Orleans Pelicans     0.508109
# 9                 Miami Heat           Orlando Magic     0.688704
# 10     Oklahoma City Thunder      Philadelphia 76ers     0.956570
# 11          Sacramento Kings            Phoenix Suns     0.625548
# 12           Toronto Raptors         Detroit Pistons     0.659972
# 13             Atlanta Hawks      Washington Wizards     0.630487
# 14            Boston Celtics           Chicago Bulls     0.622714
# 15      Los Angeles Clippers  Portland Trail Blazers     0.663305
# 16         San Antonio Spurs        Sacramento Kings     0.888076
# 17            Indiana Pacers           Brooklyn Nets     0.827450
# 18          Dallas Mavericks         Houston Rockets     0.521647
# 19           Detroit Pistons           Orlando Magic     0.650171
# 20         Charlotte Hornets              Miami Heat     0.522848
# 21     Golden State Warriors    New Orleans Pelicans     0.924534
# 22     Oklahoma City Thunder            Phoenix Suns     0.923569
# 23       Cleveland Cavaliers         Toronto Raptors     0.598518
# 24                 Utah Jazz      Los Angeles Lakers     0.907719
# 25            Indiana Pacers           Chicago Bulls     0.547829
# 26            Boston Celtics       Charlotte Hornets     0.527165
# 27       Cleveland Cavaliers           Orlando Magic     0.820060
# 28    Portland Trail Blazers          Denver Nuggets     0.743532
# 29           Milwaukee Bucks           Brooklyn Nets     0.745004
# ...                      ...                     ...          ...
# 1199        Dallas Mavericks            Phoenix Suns     0.734315
# 1200         Houston Rockets        Sacramento Kings     0.583649
# 1201          Boston Celtics           Brooklyn Nets     0.904891
# 1202           Chicago Bulls           Orlando Magic     0.628251
# 1203         Detroit Pistons      Washington Wizards     0.544281
# 1204   Golden State Warriors               Utah Jazz     0.848695
# 1205    Los Angeles Clippers         Houston Rockets     0.688942
# 1206     Cleveland Cavaliers              Miami Heat     0.694005
# 1207       Charlotte Hornets         Milwaukee Bucks     0.758661
# 1208          Indiana Pacers      Philadelphia 76ers     0.905747
# 1209       San Antonio Spurs  Portland Trail Blazers     0.827370
# 1210           Atlanta Hawks       Charlotte Hornets     0.505833
# 1211        Dallas Mavericks          Denver Nuggets     0.651933
# 1212    New Orleans Pelicans      Los Angeles Lakers     0.679251
# 1213   Oklahoma City Thunder  Minnesota Timberwolves     0.856906
# 1214        Sacramento Kings            Phoenix Suns     0.745042
# 1215          Boston Celtics         Milwaukee Bucks     0.791970
# 1216           Chicago Bulls           Brooklyn Nets     0.856809
# 1217     Cleveland Cavaliers         Toronto Raptors     0.524209
# 1218   Golden State Warriors      Los Angeles Lakers     0.980600
# 1219         Houston Rockets  Minnesota Timberwolves     0.723664
# 1220           Atlanta Hawks          Indiana Pacers     0.570838
# 1221    Los Angeles Clippers        Sacramento Kings     0.788280
# 1222        Dallas Mavericks       Memphis Grizzlies     0.529141
# 1223              Miami Heat      Washington Wizards     0.603368
# 1224         New York Knicks      Philadelphia 76ers     0.906823
# 1225   Oklahoma City Thunder          Denver Nuggets     0.835160
# 1226         Detroit Pistons           Orlando Magic     0.617216
# 1227  Portland Trail Blazers    New Orleans Pelicans     0.723673
# 1228       San Antonio Spurs               Utah Jazz     0.829257
#
# [1229 rows x 3 columns]
