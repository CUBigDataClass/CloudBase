# %%
import pandas as pd
import math
import csv
import random
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import cross_val_score

# %%
df1  =  pd.read_csv("15-16Miscellaneous_Stat.csv")
df2  =   pd.read_csv("15-16Opponent_Per_Game_Stat.csv")
df3  =   pd.read_csv("15-16Team_Per_Game_Stat.csv")
schedule = pd.read_csv("16-17Schedule.csv")
pastresult   = pd.read_csv("2015-2016_result.csv")

# %%
base_elo = 1600
team_elos = {} 
team_stats = {}
X = []
y = []
folder = 'data'

# %%
def initialize_data(Mstat, Ostat, Tstat):
    new_Mstat = Mstat.drop(['Rk', 'Arena'], axis=1)
    new_Ostat = Ostat.drop(['Rk', 'G', 'MP'], axis=1)
    new_Tstat = Tstat.drop(['Rk', 'G', 'MP'], axis=1)

    team_stats1 = pd.merge(new_Mstat, new_Ostat, how='left', on='Team')
    team_stats1 = pd.merge(team_stats1, new_Tstat, how='left', on='Team')
    return team_stats1.set_index('Team', inplace=False, drop=True)

# %%
def get_elo(team):
    try:
        return team_elos[team]
    except:
        # 当最初没有elo时，给每个队伍最初赋base_elo
        team_elos[team] = base_elo
        return team_elos[team]

# %%
def calc_elo(win_team, lose_team):
    winner_rank = get_elo(win_team)
    loser_rank = get_elo(lose_team)

    rank_diff = winner_rank - loser_rank
    exp = (rank_diff  * -1) / 400
    odds = 1 / (1 + math.pow(10, exp))
    # 根据rank级别修改K值
    if winner_rank < 2100:
        k = 32
    elif winner_rank >= 2100 and winner_rank < 2400:
        k = 24
    else:
        k = 16
    
    # 更新 rank 数值
    new_winner_rank = round(winner_rank + (k * (1 - odds)))      
    new_loser_rank = round(loser_rank + (k * (0 - odds)))
    return new_winner_rank, new_loser_rank

# %%
def  build_dataSet(all_data):
    print("Building data set..")
    X = []
    skip = 0
    for index, row in all_data.iterrows():

        Wteam = row['WTeam']
        Lteam = row['LTeam']

        #获取最初的elo或是每个队伍最初的elo值
        team1_elo = get_elo(Wteam)
        team2_elo = get_elo(Lteam)

        # 给主场比赛的队伍加上100的elo值
        if row['WLoc'] == 'H':
            team1_elo += 100
        else:
            team2_elo += 100

        # 把elo当为评价每个队伍的第一个特征值
        team1_features = [team1_elo]
        team2_features = [team2_elo]

        # 添加我们从basketball reference.com获得的每个队伍的统计信息
        for key, value in team_stats.loc[Wteam].iteritems():
            team1_features.append(value)
        for key, value in team_stats.loc[Lteam].iteritems():
            team2_features.append(value)

        # 将两支队伍的特征值随机的分配在每场比赛数据的左右两侧
        # 并将对应的0/1赋给y值
        if np.random.random() > 0.5:
            X.append(team1_features + team2_features)
            y.append(0)
        else:
            X.append(team2_features + team1_features)
            y.append(1)

        if skip == 0:
            print('X',X)
            skip = 1

        # 根据这场比赛的数据更新队伍的elo值
        new_winner_rank, new_loser_rank = calc_elo(Wteam, Lteam)
        team_elos[Wteam] = new_winner_rank
        team_elos[Lteam] = new_loser_rank

    return np.nan_to_num(X), y

# %%
if __name__ == '__main__':

    Mstat = df1
    Ostat = df2
    Tstat = df3
    team_stats = initialize_data(Mstat, Ostat, Tstat)

    result_data = pastresult
    X, y = build_dataSet(result_data)

    # 训练网络模型
    print("Fitting on %d game samples.." % len(X))

    model = linear_model.LogisticRegression()
    model.fit(X, y)

    # 利用10折交叉验证计算训练正确率
    print("Doing cross-validation..")
    print(cross_val_score(model, X, y, cv = 10, scoring='accuracy', n_jobs=-1).mean())
# Out:
# Building data set..
# X [[1700, 27.2, 32.0, 50.0, 33.0, 49.0, -2.73, 0.0, -2.74, 104.6, 107.6, 93.4, 0.255, 0.256, 0.527, 0.483, 12.6, 23.7, 0.205, 0.48700000000000004, 10.5, 75.8, 0.204, 812292.0, 38.0, 85.8, 0.44299999999999995, 7.6, 22.4, 0.341, 30.3, 63.4, 0.479, 17.5, 23.2, 0.754, 10.9, 33.3, 44.2, 20.8, 7.2, 4.2, 11.3, 18.5, 101.1, 36.9, 84.0, 0.439, 7.4, 21.5, 0.34600000000000003, 29.4, 62.5, 0.47100000000000003, 17.2, 21.4, 0.805, 10.4, 34.0, 44.4, 20.5, 5.7, 5.7, 13.4, 19.7, 98.4, 1600, 28.2, 48.0, 34.0, 51.0, 31.0, 3.61, -0.12, 3.49, 105.1, 101.4, 97.1, 0.237, 0.336, 0.552, 0.516, 13.8, 19.1, 0.185, 0.48, 14.4, 74.6, 0.19399999999999998, 690150.0, 37.1, 86.1, 0.43200000000000005, 8.3, 24.5, 0.33799999999999997, 28.9, 61.6, 0.469, 16.7, 22.1, 0.755, 11.5, 35.0, 46.5, 22.0, 8.6, 5.0, 16.1, 18.3, 99.2, 38.6, 84.4, 0.45799999999999996, 9.9, 28.4, 0.35, 28.7, 56.1, 0.512, 15.6, 20.0, 0.7829999999999999, 8.3, 33.8, 42.1, 25.6, 9.1, 5.9, 15.0, 19.1, 102.8]]
# Fitting on 1316 game samples..
# Doing cross-validation..
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.6930186480186481

# %%
def predict_winner(team_1, team_2, model):
    features = []

    # team 1，客场队伍
    features.append(get_elo(team_1))
    for key, value in team_stats.loc[team_1].iteritems():
        features.append(value)

    # team 2，主场队伍
    features.append(get_elo(team_2) + 100)
    for key, value in team_stats.loc[team_2].iteritems():
        features.append(value)

    features = np.nan_to_num(features)
    return model.predict_proba([features])

# %%
# 利用训练好的model在16-17年的比赛中进行预测

print('Predicting on new schedule..')
schedule1617 = schedule
result = []
for index, row in schedule1617.iterrows():
    team1 = row['Vteam']
    team2 = row['Hteam']
    pred = predict_winner(team1, team2, model)
    prob = pred[0][0]
    if prob > 0.5:
        winner = team1
        loser = team2
        result.append([winner, loser, prob])
    else:
        winner = team2
        loser = team1
        result.append([winner, loser, 1 - prob])

with open('16-17Result.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['win', 'lose', 'probability'])
    writer.writerows(result)
    print('done.')
pd.read_csv('16-17Result.csv',header=0)
# Out:
# Predicting on new schedule..
# done.
#                          win                    lose  probability
# 0        Cleveland Cavaliers         New York Knicks     0.841471
# 1      Golden State Warriors       San Antonio Spurs     0.532549
# 2     Portland Trail Blazers               Utah Jazz     0.525148
# 3             Boston Celtics           Brooklyn Nets     0.902771
# 4             Indiana Pacers        Dallas Mavericks     0.581528
# 5            Houston Rockets      Los Angeles Lakers     0.826485
# 6          Memphis Grizzlies  Minnesota Timberwolves     0.716562
# 7          Charlotte Hornets         Milwaukee Bucks     0.722227
# 8       New Orleans Pelicans          Denver Nuggets     0.526206
# 9                 Miami Heat           Orlando Magic     0.696855
# 10     Oklahoma City Thunder      Philadelphia 76ers     0.957853
# 11          Sacramento Kings            Phoenix Suns     0.632861
# 12           Toronto Raptors         Detroit Pistons     0.691205
# 13             Atlanta Hawks      Washington Wizards     0.632693
# 14            Boston Celtics           Chicago Bulls     0.627048
# 15      Los Angeles Clippers  Portland Trail Blazers     0.642329
# 16         San Antonio Spurs        Sacramento Kings     0.887739
# 17            Indiana Pacers           Brooklyn Nets     0.810033
# 18          Dallas Mavericks         Houston Rockets     0.514401
# 19           Detroit Pistons           Orlando Magic     0.664257
# 20         Charlotte Hornets              Miami Heat     0.513998
# 21     Golden State Warriors    New Orleans Pelicans     0.925441
# 22     Oklahoma City Thunder            Phoenix Suns     0.925998
# 23       Cleveland Cavaliers         Toronto Raptors     0.592059
# 24                 Utah Jazz      Los Angeles Lakers     0.884443
# 25            Indiana Pacers           Chicago Bulls     0.554844
# 26            Boston Celtics       Charlotte Hornets     0.509518
# 27       Cleveland Cavaliers           Orlando Magic     0.808505
# 28    Portland Trail Blazers          Denver Nuggets     0.627615
# 29           Milwaukee Bucks           Brooklyn Nets     0.756896
# ...                      ...                     ...          ...
# 1199        Dallas Mavericks            Phoenix Suns     0.748584
# 1200         Houston Rockets        Sacramento Kings     0.568276
# 1201          Boston Celtics           Brooklyn Nets     0.902771
# 1202           Chicago Bulls           Orlando Magic     0.602032
# 1203         Detroit Pistons      Washington Wizards     0.571715
# 1204   Golden State Warriors               Utah Jazz     0.853753
# 1205    Los Angeles Clippers         Houston Rockets     0.700023
# 1206     Cleveland Cavaliers              Miami Heat     0.700674
# 1207       Charlotte Hornets         Milwaukee Bucks     0.722227
# 1208          Indiana Pacers      Philadelphia 76ers     0.901868
# 1209       San Antonio Spurs  Portland Trail Blazers     0.822487
# 1210           Atlanta Hawks       Charlotte Hornets     0.514853
# 1211        Dallas Mavericks          Denver Nuggets     0.664181
# 1212    New Orleans Pelicans      Los Angeles Lakers     0.690811
# 1213   Oklahoma City Thunder  Minnesota Timberwolves     0.842046
# 1214        Sacramento Kings            Phoenix Suns     0.743923
# 1215          Boston Celtics         Milwaukee Bucks     0.806320
# 1216           Chicago Bulls           Brooklyn Nets     0.835811
# 1217     Cleveland Cavaliers         Toronto Raptors     0.515505
# 1218   Golden State Warriors      Los Angeles Lakers     0.979543
# 1219         Houston Rockets  Minnesota Timberwolves     0.739403
# 1220           Atlanta Hawks          Indiana Pacers     0.546255
# 1221    Los Angeles Clippers        Sacramento Kings     0.787730
# 1222        Dallas Mavericks       Memphis Grizzlies     0.503230
# 1223              Miami Heat      Washington Wizards     0.605480
# 1224         New York Knicks      Philadelphia 76ers     0.888587
# 1225   Oklahoma City Thunder          Denver Nuggets     0.859345
# 1226         Detroit Pistons           Orlando Magic     0.592267
# 1227  Portland Trail Blazers    New Orleans Pelicans     0.734339
# 1228       San Antonio Spurs               Utah Jazz     0.845947
#
# [1229 rows x 3 columns]
